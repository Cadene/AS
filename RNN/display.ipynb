# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_curve = pd.read_csv('data/toy_curve.csv', sep=',')
df_disp = pd.read_csv('data/toy_disp.csv', sep=',')
#df_data = pd.read_csv('data/toy.csv', sep=',')

# %%
plt.figure()
plt.plot(df_curve.x, df_curve.y)
plt.plot(df_disp.x1, df_disp.y_pred)
plt.plot(df_disp.x1, df_disp.y_true)
#plt.scatter(df_data.x1, df_data.y1)
#plt.scatter(df_data.x2, df_data.y2, c='red')
#plt.scatter(df_data.x3, df_data.y3, c='green')

# %%
df_disp
# Out:
#           x1        x2        x3     y_true    y_pred
# 0   3.330033  1.341420  0.206182   0.000000  0.179736
# 1   3.356429  1.621521  0.115927   0.101010  0.120535
# 2   3.349452  1.902259  0.075817   0.202020  0.211916
# 3   3.313523  2.175104  0.087172   0.303030  0.322475
# 4   3.254192  2.432098  0.149560   0.404040  0.353453
# 5   3.177882  2.666158  0.260809   0.505051  0.468023
# 6   3.091597  2.871333  0.417106   0.606061  0.596647
# 7   3.002608  3.043023  0.613149   0.707071  0.636790
# 8   2.918125  3.178133  0.842357   0.808081  0.692632
# 9   2.844979  3.275171  1.097130   0.909091  1.027230
# 10  2.789318  3.334273  1.369152   1.010101  1.293537
# 11  2.756336  3.357170  1.649710   1.111111  0.865105
# 12  2.750040  3.347079  1.930035   1.212121  0.482489
# 13  2.773070  3.308543  2.201641   1.313131  1.316452
# 14  2.826575  3.247213  2.456644   1.414141  2.236449
# 15  2.910157  3.169583  2.688062   1.515152  1.956790
# ...
